# %% [markdown]
# ## **Section 6 : Custom Calculations**

# %% [markdown]
# ### 6.1 Introduction to Custom Calculations

# %% [markdown]
# Until now, we've worked with data that is already added in the table. Now we'll create or extract the data and perform some calculations to create some useful classifications and filter out the data.

# %% [markdown]
# ### 6.2 Create Calculations

# %% [markdown]
# Now, we'll try to create a new column containing the `profit` as a percentage of the `sales`. We'll not take any new data, we'll create it from the existing data only.

# %% [markdown]
# So, just like we created the `Sales Total` column in the previous section, we'll make a **`Ratio_Total`** column.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 6.3 Year Month and Day

# %% [markdown]
# Now we'll extract **Year**, **Month** and **Day of the Month** from the `Order Date` column

# %% [markdown]
# There are pre-defined functions of **`Year()`**, **`Month()`**, **`DayOfMonth()`** in Google Data Studio which perform this task.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 6.4 Case Statement

# %% [markdown]
# The use of **`Case Statement`** is just like if-else statement. We perform one operation if a condition is fulfilled, else go with another operation if it isn't fulfilled.

# %% [markdown]
# Let's Add a Field with the name "Greater than 200" to classify whether the sale is more than 200 or not.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As show below, we can count the records that are greater than 200 and the ones that are less than 200.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If we want to create a 3rd condition, we can create it by the following way:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 6.5 Comparisons

# %% [markdown]
# This feature is used to comparison of values of a metric for certain time period with a variety of date ranges available for the convenience of user.

# %% [markdown]
# Click on **`Comparison date range`** button present in the `Data` panel. It provides a variety of pre-defined options like `Previous Period`, `Previous Year` etc. for time saving.
#
# `Previous Period` takes the same duration of the custom selected time period.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can select various formatting options for the Comparison Metric like color of increment/decrement, Decimal Precision, Absolute change/Percentage change etc.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Exercises
#
# Download this worksheet for this Exercise:
# [Worksheet](https://docs.google.com/spreadsheets/d/1VioS04TIssDLzUtm4RdpoIJBh5rf4hYVzCMCJaTfi8Y/edit?usp=sharing)
#
# **Ex 6.1** : Create the following fields:
#
# 1) Average Sales
#
# 2) Highest Sales
#
# 3) No. of Products
#
# 4) Average Sales per product
#
#
# **Ex 6.2** : As learnt in section 6.3, display the data month-wise and Day-of-the-month wise
#
# **Ex 6.3** : Create a new field to display the Weekday
#
# **Ex 6.4** : Cerate a table displaying the Sales by Product Category and the Weekday
#
# **Ex 6.5** : Create a Table displaying the number of orders that had a profit over $500, over $200 and less than $200.
