# %% [markdown]
# # Exploring Two or More Variables

# %% [markdown]
# ## Types of Relationship

# %% [markdown]
# ### 1.Unrelated

# %% [markdown]
# ### 2.Linear
#
# The linear correlation coefficient measures the strength and direction of the linear relationship between two variables  𝑥  and  𝑦 .
# The sign of the linear correlation coefficient indicates the direction of the linear relationship between  𝑥  and  𝑦 .
# When  𝑟  is near  1  or  −1  the linear relationship is strong; when it is near  0  the linear relationship is weak.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3.Non Linear
#
# Correlation is said to be non linear if the ratio of change is not constant. In other words, when all the points on the scatter diagram tend to lie near a smooth curve, the correlation is said to be non linear (curvilinear). This is shown in the figure on the right below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # EXCERCISE1:Compute the linear correlation coefficient for the height and weight pairs
#
# **SOLN:**Even for small data sets like this one computations are too long to do completely by hand. In actual practice the data are entered into a calculator or computer and a statistics program is used. In order to clarify the meaning of the formulas we will display the data and related quantities in tabular form. For each (x,y) pair we compute three numbers: x2, xy, and y2, as shown in the table provided. In the last line of the table we have the sum of the numbers in each column. Using them we compute:

# %%
import pandas as pd
df=pd.read_csv('https://drive.google.com/uc?id=1YiUjgYjIHqtbK3RQVT5cHG8_9uRyD_Vg')
df
# Out:
#    Unnamed: 0    x     y     x2      xy      y2
# 0         NaN   68   151   4624   10268   22801
# 1         NaN   69   146   4761   10074   21316
# 2         NaN   70   157   4900   10990   24649
# 3         NaN   70   164   4900   11480   26896
# 4         NaN   71   171   5041   12141   29241
# 5         NaN   72   160   5184   11520   25600
# 6         NaN   72   163   5184   11736   26569
# 7         NaN   72   180   5184   12960   32400
# 8         NaN   73   170   5329   12410   28900
# 9         NaN   73   175   5329   12775   30625
# 10        NaN   74   178   5476   13172   31684
# 11        NaN   75   188   5625   14100   35344
# 12          Σ  859  2003  61537  143626  336025

# %% [markdown]
# ![Screenshot 2022-04-08 at 6.34.26 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Excercise2:
# For all the sample data given:
#
# 1. Draw the scatter plot.
# 2. Based on the scatter plot, predict the sign of the linear correlation coefficient. Explain your answer.
# 3. Compute the linear correlation coefficient and compare its sign to your answer to part (b).

# %% [markdown]
# ## Q1.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ANS:** r=0.921

# %% [markdown]
# ## Q2
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ANS:** r=−0.794

# %% [markdown]
# # Excercise 3:
#
# Compute the linear correlation coefficient for the sample data summarized by the following information:

# %% [markdown]
# ## Q1
# n=5
#
# Σy=24
#
# Σx=25
#
# Σy2=134
#
# 1≤x≤9
#
# Σx2=165
#
# Σxy=144

# %% [markdown]
# ## Q2:
# n=5
#
# Σy=18
#
# Σx=31
#
# Σy2=90
#
# 2≤x≤12
#
# Σx2=253
#
# Σxy=148
