# %% [markdown]
# ### 7.1 Introduction to Time Series Graphs

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Time Series graphs are a very useful tool when trying to visualize or identify some trend in the value of any particular metric. It also helps in identifying the volatility or stability in a trend as well.

# %% [markdown]
# ### 7.2 Create Time Series Graph

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The metrics and Dimensions used are:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Since we were not able to see the available data points clearly in the day-wise time series graph, so we created a drill-down of the same data containing the year-wise, month-wise and day-wise data. The drill-down view of the same data is as follows :

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# There is a section named **`Breakdown Dimension`** in the `Data` panel. This basically acts as a legend for time-series graphs. For Example, if we select `channel` as the `Breakdown Dimension`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can also plot multiple Metrics as well. Like in the following graph we have plotted Sales and Profit simultaneously.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# There are a large number of `Style` options available with us for time series graphs.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can show the connecting data points as a `Bar` instead of a `Line`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can draw trend lines as well. These can be `Linear`,`Exponential` or `polynomial`. The red line shown in the below figure is the Trend line of the polynomial form.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can add Reference Lines in the graph as well.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 7.3 Changing Time Periods

# %% [markdown]
# To change the Time Period, click on the pencil icon on the side of the `Dimension`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This opens the following pop-up. Click on the desired format that you want and the axis of the graph will change to that time scale.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here, we've plotted the `Sales` of different `Product Category` with change in Year Quarter, Year and Monthly basis.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 7.4 Styles and Formatting

# %% [markdown]
# We can create Trend lines in our graph. These can linear, exponential or polynomial in form.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can also draw reference lines in our graphs. These can be based on some Metrics, or be constant or a parameter as well. As shown below, we've plotted the 90th and 10th percentile as the reference lines for our graph. Further, formatting of these reference lines can be done as well.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 7.5 Time Series Chart Options

# %% [markdown]
# As did earlier, we can also compare the graphs obtained for some custom date period with some desized period of time.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# After this, we can apply the desired filters and other classification and formatting as well.

# %% [markdown]
# ### 7.6 Area Graph

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can style the Area Graph in multiple ways. It allows 100% stacking as well, where-in it displays the y-axis in the form of percentages and then displays various categories of data as a percentage. We can also add reference lines as we have seen in the previous sections.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Exercises
#
# Download this worksheet for this Exercise:
# [Worksheet](https://docs.google.com/spreadsheets/d/1VioS04TIssDLzUtm4RdpoIJBh5rf4hYVzCMCJaTfi8Y/edit?usp=sharing)
#
# **Ex 7.1** : Create the following Time Series graphs:
#
# 1) Sales by Year
#
# 2) Sales by Year and Month
#
# 3) Sales by Day of the Week
#
# 4) Sales by Year and Month for the Asian Region
#
# 5) Stacked Area Graph displaying Sales by Month for 2018 for each channel. Use a fitler to change the country.
#
# **Ex 7.2** : Show a chart displaying the Sales in different months of the time period. Identify the exponential trend line and draw the 90th and 50th percentile reference lines.
#
# **Ex 7.3** : Plot the profits for different sub categories simultaneously on a time series graph
#
# **Ex 7.4** : Create a 100% stacking Area graph of different product category with year and determine the sales of Cell Phones in 2018
