# %% [markdown]
# ## **Section 8 : Other Visualizations**

# %% [markdown]
# ### 8.1 Introduction to Standard Visualizations

# %% [markdown]
# In this section, we'll be exploring different visualization tools like `Column and Bar Graphs`,`Pie Charts`,`TreeMaps` etc. for visually finding out  the magnitude difference, percentage share etc. Let's begin with learning these Graphs:

# %% [markdown]
# ### 8.2 Column and Bar Graphs

# %% [markdown]
# The column graph is very useful in comparing different values with the help of visualization and find out the magnitude of difference between the values for the same.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can add Drill-Down and sort the colums as we wish according to the category from the button available at the top right corner of the chart. We can show the details of a particular bar by hovering over it by enabling the **`Show Total Card`** option.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can do a number of formatting activities for our column chart.
# We can create stacked bars, show total cards, change bar colors, add Labels etc.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can also make Bar plots in Google Data Studio and add the desired formatting and other styles.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 8.3 Pie Graphs

# %% [markdown]
# These are mainly used to know the percentage contribution of some dimension in the metrics

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In this also, we can style the Pie Graph in numerous ways as shown in the style bar. Try exploring these options on your own.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 8.4 Geographical Analysis

# %% [markdown]
# We can add Geographical charts in Google Data Studio as well.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can zoom in at different sections of the map as well. Click on the Zoom option available in the `Data` panel and select the desired zoomed view.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Plotting the Geo Chart and Google Maps

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 8.5 TreeMap Graph

# %% [markdown]
# A TreeMap basically shows the values of a category in the form of blocksize. We can also use colors to visually create an image representing higha nd low values of any particular category as well.~

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 8.6 Scatterplot Graph

# %% [markdown]
# The next example of a graph that we're going to be looking at is our scatterplot.
# Scatterplot is used for is to understand if there is correlation between two values.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can also use `Bubble Size Metric` to make the size of the scatter plot points proportional to their value.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 8.7 Custom Visualization

# %% [markdown]
# The custom visualization option is available in the main ribbon available on the home page of our report page.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let's say we selected the Gauge option available with us:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can style this in various ways, we can add the limit colors to  this gauge. We can select the range of the gauge etc.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Exercises
# Download this worksheet for this Exercise:
# [Worksheet](https://docs.google.com/spreadsheets/d/1VioS04TIssDLzUtm4RdpoIJBh5rf4hYVzCMCJaTfi8Y/edit?usp=sharing)
#
# **Ex 8.1** : Create a stacked bar chart of sales in different years and explore what is the significance of Show Total Card option in Style Panel
#
# **Ex 8.2** :Create a pie chart displaying the percentage share of different regions in Sales. Then convert the same pie chart into doughnout chart. The highest percentage should be displayed in green color, whereas the least one in red.
#
# **Ex 8.3** :Create a quarter-wise sales bar chart. Display the sales in Europe in all the created charts using interactive filter
#
# **Ex 8.4** :Display the profit of different countries of Asia on a map using (a) bubbles and (b) color scale
#
# **Ex 8.5** :Convert a table displaying the sales of different regions into a bar chart, pie chart and TreeMap
