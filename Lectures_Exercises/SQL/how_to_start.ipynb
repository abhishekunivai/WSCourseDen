# %% [markdown]
# ## How to Start?

# %% [markdown]
# Step 1 - Download MySQL Community Server using this link - https://dev.mysql.com/downloads/mysql/

# %% [markdown]
# Step 2 - Follow the setup steps and set root password for mysql

# %% [markdown]
# Step 3 - Open MySQL Command Line Client

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Step 4 - Enter root password

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Step 5 - Begin the fun
