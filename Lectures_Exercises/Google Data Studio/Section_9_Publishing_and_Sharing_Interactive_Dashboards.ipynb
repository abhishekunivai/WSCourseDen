# %% [markdown]
# ## **Section 9 : Publishing and Sharing Interactive Dashboards**

# %% [markdown]
# ### 9.1 Introduction to Dashboards

# %% [markdown]
# ![](https://s3.amazonaws.com/Supermetrics/images/adw1.jpg)
# An example of pre-defined template in Google Data Studio

# %% [markdown]
# So, until now in this course we've learned a variety of visualization tools and techniques. Now, we'll try to combine all the learning that we've done into a single report so that we can present the visualizations to someone else or share these with him or her.

# %% [markdown]
# ### 9.2 Creating a Dashboard

# %% [markdown]
# We will be creating a Dashboard to show-case our skills learnt in the previous sections and make use of visualization tools to make the data easy to understand and user-friendly in nature.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 9.4 Sharing Dashboards

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can directly invite collaborators with their e-mail IDs or send them the link of our dashboard, or embed our report in a webpage or else download it in our device and then further share it with whoever we want to.

# %% [markdown]
# ### Exercises
#
# Download this worksheet for this Exercise:
# [Worksheet](https://docs.google.com/spreadsheets/d/1VioS04TIssDLzUtm4RdpoIJBh5rf4hYVzCMCJaTfi8Y/edit?usp=sharing)
#
#
# **Ex 9.1** : Create a Dashboard containing:
# Create a header with the title – Sales Report
# Create the following Card Visualizations
#
# • Total Sales
#
# • Total Profit
#
# • Average of Sales
#
# • Average of Profit
#
# • Number of Products Sold (Product Name)
#
# • Line graph displaying the Sales by Year and Quarter
#
# • Bar Graph displaying Sales by Product Category
#
# • Top 10 Country Sales Column graph
#
# • Profit by Channel – Donut Graph – Add percentage data labels
#
# • Region as a Filter
