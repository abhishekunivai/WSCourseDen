# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekunivai/WSCourseDen/blob/main/WSCourseDen/Lectures_Exercises/Statistics/Section_10_Blending_and_Joining_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Section 10 : Blending and Joining data**

# %% [markdown]
# Before starting this section, download the spreadsheets required for this activity from this link:
#
# [Worksheet 1](https://docs.google.com/spreadsheets/d/191SBacMfNq4tv8XYIuf3UhJQp0D0_RX-ojTsTG1-SBI/edit?usp=sharing)
#
# [Worksheet 2](https://docs.google.com/spreadsheets/d/1fK04A-vUkQSg64dQXiQqd_jAAV3EP37v1TLJoHAzwN0/edit?usp=sharing)

# %% [markdown]
# ### 10.1 Preparing Files for Data Blending

# %% [markdown]
# One thing to keep in mind while blending is that both the data sources must have atleast one common column to perform Data Blending.

# %% [markdown]
# Firstly we'll create the spreadsheets containing the data that we need to work on for blending by importing the data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now, we'll import these spreadsheets into Google Data Studio

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 10.2 Data Blending

# %% [markdown]
# Click on Blend Data button present in Data Source sectin in Data panel.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Select the Data Sources and click on the condition button and select the common column in both the worksheets. In this case, it is the EmployeeID column.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As we can see that the Dept was a column in `Master` worksheet, and `Cost` was a column in the `Worksheet` worksheet. And we can see from the data below that the stats of both the tables match with each other.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If we forgot to add any dimension/metric etc, click on `Resource` button present on the top ribbon. Then click on `Manage blends` button.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This will open a pop-up shown below. Click on Edit button.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This will pop-up the same window which came while implementing the data blending

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 10.3 Google Analytics

# %% [markdown]
# Just like in the previous sections, we worked on connecting Google Sheets with Google Data Studio, similarly we can connect Google Analytics as well to view the visualizations in an interactive manner.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Click on Add Data and select Google Analytics. Now, rest all is just similar to the way we connected Google Sheets

# %% [markdown]
# ### Exercises
#
# Download these worksheets for this Exercise:
#
# [Worksheet 1](https://docs.google.com/spreadsheets/d/191SBacMfNq4tv8XYIuf3UhJQp0D0_RX-ojTsTG1-SBI/edit?usp=sharing)
#
# [Worksheet 2](https://docs.google.com/spreadsheets/d/1fK04A-vUkQSg64dQXiQqd_jAAV3EP37v1TLJoHAzwN0/edit?usp=sharing)
#
# **Ex 10.1** : Create a table joined between the two worksheets and determine whether male employees did more courses or female? Also determine the cost of the total and average cost of the courses.
#
# **Ex 10.2** : Find out which job grade did the minimum number of courses.
#
# **Ex 10.3** : Find out the average number of courses done by married and single employees.
#
# **Ex 10.4** : Find out the minimum and average number of courses done by an employee with salary greater than 1000 and  less than 1000.
#
# **Ex 10.5** : On which date were the most number of courses started?
